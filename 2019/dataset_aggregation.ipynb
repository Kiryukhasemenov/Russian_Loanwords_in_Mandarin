# %%
import numpy as np
import pandas as pd
import textdistance
#https://pypi.org/project/textdistance/
import os

# %% [markdown]
# ### This code is used to add the Xinhua transliteration to Wikidata dataset, and then to add metrics

# %%
from transliterator import Transliterator as T

table=pd.read_csv('translit_pdf_version.csv',sep=';')

# %%
filename = 'data_preprocessed_no_duplicates.csv'
filename_2 = 'data_preprocessed_with_duplicates.csv'
df = pd.read_csv(filename_2)
df.head()
# Out:
#    wiki_id label_zh    label_ru                              country  type
# 0   265997     伊曼德拉     Имандра  http://www.wikidata.org/entity/Q159  lake
# 1   166162      奥涅加    Онежское  http://www.wikidata.org/entity/Q159  lake
# 2   233071       汉泰  Хантайское  http://www.wikidata.org/entity/Q159  lake
# 3   245763   奥特拉德诺耶    Отрадное  http://www.wikidata.org/entity/Q159  lake
# 4   117036     绍托泽罗    Шотозеро  http://www.wikidata.org/entity/Q159  lake

# %%
df.shape
# Out:
# (36261, 5)

# %%
c_dict = {"http://www.wikidata.org/entity/Q159": 'Russia', "http://www.wikidata.org/entity/Q212": 'Ukraine', 
                                "http://www.wikidata.org/entity/Q15180":'USSR',"http://www.wikidata.org/entity/Q34266":'Russian Empire',
                               "http://www.wikidata.org/entity/Q184":'Belarus', "http://www.wikidata.org/entity/Q907112":'Transnistria'}
t_dict = {"lake": 1, "island": 2, "river": 3, "mountain": 4,
                                  "settlement": 5, "person": 6}
#df = df.replace(cleanup_nums, inplace=True)

# %%
df.replace(c_dict, inplace=True)

# %%
df.head()
# Out:
#    wiki_id label_zh    label_ru country  type
# 0   265997     伊曼德拉     Имандра  Russia  lake
# 1   166162      奥涅加    Онежское  Russia  lake
# 2   233071       汉泰  Хантайское  Russia  lake
# 3   245763   奥特拉德诺耶    Отрадное  Russia  lake
# 4   117036     绍托泽罗    Шотозеро  Russia  lake

# %%
df = df[~df['label_zh'].str.contains("[a-zA-Z]").fillna(False)]

# %%
df.shape
# Out:
# (36257, 5)

# %%
df.dtypes
# Out:
# wiki_id      int64
# label_zh    object
# label_ru    object
# country     object
# type        object
# dtype: object

# %%
df.to_csv('data_with_duplicates_pre_final.csv', index=False)

# %% [markdown]
# ## creating "orthodox" Xinhua transliteration

# %%
with open('data_with_duplicates_pre_final.csv', 'r', encoding='utf-8') as src:
    data = src.readlines()
    length = len(data)-1

# %%
data_chunks = [data[x:x+100] for x in range(0, len(data), 100)]

# %%
import os
os.mkdir('data_with_duplicates_by_parts')

# %%
length = 36257

# %%
filenames = ['data_with_dupl_pt_'+str(i) for i in range(1, (length//100+2))]
filenames
# Out:
# ['data_with_dupl_pt_1',
#  'data_with_dupl_pt_2',
#  'data_with_dupl_pt_3',
#  'data_with_dupl_pt_4',
#  'data_with_dupl_pt_5',
#  'data_with_dupl_pt_6',
#  'data_with_dupl_pt_7',
#  'data_with_dupl_pt_8',
#  'data_with_dupl_pt_9',
#  'data_with_dupl_pt_10',
#  'data_with_dupl_pt_11',
#  'data_with_dupl_pt_12',
#  'data_with_dupl_pt_13',
#  'data_with_dupl_pt_14',
#  'data_with_dupl_pt_15',
#  'data_with_dupl_pt_16',
#  'data_with_dupl_pt_17',
#  'data_with_dupl_pt_18',
#  'data_with_dupl_pt_19',
#  'data_with_dupl_pt_20',
#  'data_with_dupl_pt_21',
#  'data_with_dupl_pt_22',
#  'data_with_dupl_pt_23',
#  'data_with_dupl_pt_24',
#  'data_with_dupl_pt_25',
#  'data_with_dupl_pt_26',
#  'data_with_dupl_pt_27',
#  'data_with_dupl_pt_28',
#  'data_with_dupl_pt_29',
#  'data_with_dupl_pt_30',
#  'data_with_dupl_pt_31',
#  'data_with_dupl_pt_32',
#  'data_with_dupl_pt_33',
#  'data_with_dupl_pt_34',
#  'data_with_dupl_pt_35',
#  'data_with_dupl_pt_36',
#  'data_with_dupl_pt_37',
#  'data_with_dupl_pt_38',
#  'data_with_dupl_pt_39',
#  'data_with_dupl_pt_40',
#  'data_with_dupl_pt_41',
#  'data_with_dupl_pt_42',
#  'data_with_dupl_pt_43',
#  'data_with_dupl_pt_44',
#  'data_with_dupl_pt_45',
#  'data_with_dupl_pt_46',
#  'data_with_dupl_pt_47',
#  'data_with_dupl_pt_48',
#  'data_with_dupl_pt_49',
#  'data_with_dupl_pt_50',
#  'data_with_dupl_pt_51',
#  'data_with_dupl_pt_52',
#  'data_with_dupl_pt_53',
#  'data_with_dupl_pt_54',
#  'data_with_dupl_pt_55',
#  'data_with_dupl_pt_56',
#  'data_with_dupl_pt_57',
#  'data_with_dupl_pt_58',
#  'data_with_dupl_pt_59',
#  'data_with_dupl_pt_60',
#  'data_with_dupl_pt_61',
#  'data_with_dupl_pt_62',
#  'data_with_dupl_pt_63',
#  'data_with_dupl_pt_64',
#  'data_with_dupl_pt_65',
#  'data_with_dupl_pt_66',
#  'data_with_dupl_pt_67',
#  'data_with_dupl_pt_68',
#  'data_with_dupl_pt_69',
#  'data_with_dupl_pt_70',
#  'data_with_dupl_pt_71',
#  'data_with_dupl_pt_72',
#  'data_with_dupl_pt_73',
#  'data_with_dupl_pt_74',
#  'data_with_dupl_pt_75',
#  'data_with_dupl_pt_76',
#  'data_with_dupl_pt_77',
#  'data_with_dupl_pt_78',
#  'data_with_dupl_pt_79',
#  'data_with_dupl_pt_80',
#  'data_with_dupl_pt_81',
#  'data_with_dupl_pt_82',
#  'data_with_dupl_pt_83',
#  'data_with_dupl_pt_84',
#  'data_with_dupl_pt_85',
#  'data_with_dupl_pt_86',
#  'data_with_dupl_pt_87',
#  'data_with_dupl_pt_88',
#  'data_with_dupl_pt_89',
#  'data_with_dupl_pt_90',
#  'data_with_dupl_pt_91',
#  'data_with_dupl_pt_92',
#  'data_with_dupl_pt_93',
#  'data_with_dupl_pt_94',
#  'data_with_dupl_pt_95',
#  'data_with_dupl_pt_96',
#  'data_with_dupl_pt_97',
#  'data_with_dupl_pt_98',
#  'data_with_dupl_pt_99',
#  'data_with_dupl_pt_100',
#  'data_with_dupl_pt_101',
#  'data_with_dupl_pt_102',
#  'data_with_dupl_pt_103',
#  'data_with_dupl_pt_104',
#  'data_with_dupl_pt_105',
#  'data_with_dupl_pt_106',
#  'data_with_dupl_pt_107',
#  'data_with_dupl_pt_108',
#  'data_with_dupl_pt_109',
#  'data_with_dupl_pt_110',
#  'data_with_dupl_pt_111',
#  'data_with_dupl_pt_112',
#  'data_with_dupl_pt_113',
#  'data_with_dupl_pt_114',
#  'data_with_dupl_pt_115',
#  'data_with_dupl_pt_116',
#  'data_with_dupl_pt_117',
#  'data_with_dupl_pt_118',
#  'data_with_dupl_pt_119',
#  'data_with_dupl_pt_120',
#  'data_with_dupl_pt_121',
#  'data_with_dupl_pt_122',
#  'data_with_dupl_pt_123',
#  'data_with_dupl_pt_124',
#  'data_with_dupl_pt_125',
#  'data_with_dupl_pt_126',
#  'data_with_dupl_pt_127',
#  'data_with_dupl_pt_128',
#  'data_with_dupl_pt_129',
#  'data_with_dupl_pt_130',
#  'data_with_dupl_pt_131',
#  'data_with_dupl_pt_132',
#  'data_with_dupl_pt_133',
#  'data_with_dupl_pt_134',
#  'data_with_dupl_pt_135',
#  'data_with_dupl_pt_136',
#  'data_with_dupl_pt_137',
#  'data_with_dupl_pt_138',
#  'data_with_dupl_pt_139',
#  'data_with_dupl_pt_140',
#  'data_with_dupl_pt_141',
#  'data_with_dupl_pt_142',
#  'data_with_dupl_pt_143',
#  'data_with_dupl_pt_144',
#  'data_with_dupl_pt_145',
#  'data_with_dupl_pt_146',
#  'data_with_dupl_pt_147',
#  'data_with_dupl_pt_148',
#  'data_with_dupl_pt_149',
#  'data_with_dupl_pt_150',
#  'data_with_dupl_pt_151',
#  'data_with_dupl_pt_152',
#  'data_with_dupl_pt_153',
#  'data_with_dupl_pt_154',
#  'data_with_dupl_pt_155',
#  'data_with_dupl_pt_156',
#  'data_with_dupl_pt_157',
#  'data_with_dupl_pt_158',
#  'data_with_dupl_pt_159',
#  'data_with_dupl_pt_160',
#  'data_with_dupl_pt_161',
#  'data_with_dupl_pt_162',
#  'data_with_dupl_pt_163',
#  'data_with_dupl_pt_164',
#  'data_with_dupl_pt_165',
#  'data_with_dupl_pt_166',
#  'data_with_dupl_pt_167',
#  'data_with_dupl_pt_168',
#  'data_with_dupl_pt_169',
#  'data_with_dupl_pt_170',
#  'data_with_dupl_pt_171',
#  'data_with_dupl_pt_172',
#  'data_with_dupl_pt_173',
#  'data_with_dupl_pt_174',
#  'data_with_dupl_pt_175',
#  'data_with_dupl_pt_176',
#  'data_with_dupl_pt_177',
#  'data_with_dupl_pt_178',
#  'data_with_dupl_pt_179',
#  'data_with_dupl_pt_180',
#  'data_with_dupl_pt_181',
#  'data_with_dupl_pt_182',
#  'data_with_dupl_pt_183',
#  'data_with_dupl_pt_184',
#  'data_with_dupl_pt_185',
#  'data_with_dupl_pt_186',
#  'data_with_dupl_pt_187',
#  'data_with_dupl_pt_188',
#  'data_with_dupl_pt_189',
#  'data_with_dupl_pt_190',
#  'data_with_dupl_pt_191',
#  'data_with_dupl_pt_192',
#  'data_with_dupl_pt_193',
#  'data_with_dupl_pt_194',
#  'data_with_dupl_pt_195',
#  'data_with_dupl_pt_196',
#  'data_with_dupl_pt_197',
#  'data_with_dupl_pt_198',
#  'data_with_dupl_pt_199',
#  'data_with_dupl_pt_200',
#  'data_with_dupl_pt_201',
#  'data_with_dupl_pt_202',
#  'data_with_dupl_pt_203',
#  'data_with_dupl_pt_204',
#  'data_with_dupl_pt_205',
#  'data_with_dupl_pt_206',
#  'data_with_dupl_pt_207',
#  'data_with_dupl_pt_208',
#  'data_with_dupl_pt_209',
#  'data_with_dupl_pt_210',
#  'data_with_dupl_pt_211',
#  'data_with_dupl_pt_212',
#  'data_with_dupl_pt_213',
#  'data_with_dupl_pt_214',
#  'data_with_dupl_pt_215',
#  'data_with_dupl_pt_216',
#  'data_with_dupl_pt_217',
#  'data_with_dupl_pt_218',
#  'data_with_dupl_pt_219',
#  'data_with_dupl_pt_220',
#  'data_with_dupl_pt_221',
#  'data_with_dupl_pt_222',
#  'data_with_dupl_pt_223',
#  'data_with_dupl_pt_224',
#  'data_with_dupl_pt_225',
#  'data_with_dupl_pt_226',
#  'data_with_dupl_pt_227',
#  'data_with_dupl_pt_228',
#  'data_with_dupl_pt_229',
#  'data_with_dupl_pt_230',
#  'data_with_dupl_pt_231',
#  'data_with_dupl_pt_232',
#  'data_with_dupl_pt_233',
#  'data_with_dupl_pt_234',
#  'data_with_dupl_pt_235',
#  'data_with_dupl_pt_236',
#  'data_with_dupl_pt_237',
#  'data_with_dupl_pt_238',
#  'data_with_dupl_pt_239',
#  'data_with_dupl_pt_240',
#  'data_with_dupl_pt_241',
#  'data_with_dupl_pt_242',
#  'data_with_dupl_pt_243',
#  'data_with_dupl_pt_244',
#  'data_with_dupl_pt_245',
#  'data_with_dupl_pt_246',
#  'data_with_dupl_pt_247',
#  'data_with_dupl_pt_248',
#  'data_with_dupl_pt_249',
#  'data_with_dupl_pt_250',
#  'data_with_dupl_pt_251',
#  'data_with_dupl_pt_252',
#  'data_with_dupl_pt_253',
#  'data_with_dupl_pt_254',
#  'data_with_dupl_pt_255',
#  'data_with_dupl_pt_256',
#  'data_with_dupl_pt_257',
#  'data_with_dupl_pt_258',
#  'data_with_dupl_pt_259',
#  'data_with_dupl_pt_260',
#  'data_with_dupl_pt_261',
#  'data_with_dupl_pt_262',
#  'data_with_dupl_pt_263',
#  'data_with_dupl_pt_264',
#  'data_with_dupl_pt_265',
#  'data_with_dupl_pt_266',
#  'data_with_dupl_pt_267',
#  'data_with_dupl_pt_268',
#  'data_with_dupl_pt_269',
#  'data_with_dupl_pt_270',
#  'data_with_dupl_pt_271',
#  'data_with_dupl_pt_272',
#  'data_with_dupl_pt_273',
#  'data_with_dupl_pt_274',
#  'data_with_dupl_pt_275',
#  'data_with_dupl_pt_276',
#  'data_with_dupl_pt_277',
#  'data_with_dupl_pt_278',
#  'data_with_dupl_pt_279',
#  'data_with_dupl_pt_280',
#  'data_with_dupl_pt_281',
#  'data_with_dupl_pt_282',
#  'data_with_dupl_pt_283',
#  'data_with_dupl_pt_284',
#  'data_with_dupl_pt_285',
#  'data_with_dupl_pt_286',
#  'data_with_dupl_pt_287',
#  'data_with_dupl_pt_288',
#  'data_with_dupl_pt_289',
#  'data_with_dupl_pt_290',
#  'data_with_dupl_pt_291',
#  'data_with_dupl_pt_292',
#  'data_with_dupl_pt_293',
#  'data_with_dupl_pt_294',
#  'data_with_dupl_pt_295',
#  'data_with_dupl_pt_296',
#  'data_with_dupl_pt_297',
#  'data_with_dupl_pt_298',
#  'data_with_dupl_pt_299',
#  'data_with_dupl_pt_300',
#  'data_with_dupl_pt_301',
#  'data_with_dupl_pt_302',
#  'data_with_dupl_pt_303',
#  'data_with_dupl_pt_304',
#  'data_with_dupl_pt_305',
#  'data_with_dupl_pt_306',
#  'data_with_dupl_pt_307',
#  'data_with_dupl_pt_308',
#  'data_with_dupl_pt_309',
#  'data_with_dupl_pt_310',
#  'data_with_dupl_pt_311',
#  'data_with_dupl_pt_312',
#  'data_with_dupl_pt_313',
#  'data_with_dupl_pt_314',
#  'data_with_dupl_pt_315',
#  'data_with_dupl_pt_316',
#  'data_with_dupl_pt_317',
#  'data_with_dupl_pt_318',
#  'data_with_dupl_pt_319',
#  'data_with_dupl_pt_320',
#  'data_with_dupl_pt_321',
#  'data_with_dupl_pt_322',
#  'data_with_dupl_pt_323',
#  'data_with_dupl_pt_324',
#  'data_with_dupl_pt_325',
#  'data_with_dupl_pt_326',
#  'data_with_dupl_pt_327',
#  'data_with_dupl_pt_328',
#  'data_with_dupl_pt_329',
#  'data_with_dupl_pt_330',
#  'data_with_dupl_pt_331',
#  'data_with_dupl_pt_332',
#  'data_with_dupl_pt_333',
#  'data_with_dupl_pt_334',
#  'data_with_dupl_pt_335',
#  'data_with_dupl_pt_336',
#  'data_with_dupl_pt_337',
#  'data_with_dupl_pt_338',
#  'data_with_dupl_pt_339',
#  'data_with_dupl_pt_340',
#  'data_with_dupl_pt_341',
#  'data_with_dupl_pt_342',
#  'data_with_dupl_pt_343',
#  'data_with_dupl_pt_344',
#  'data_with_dupl_pt_345',
#  'data_with_dupl_pt_346',
#  'data_with_dupl_pt_347',
#  'data_with_dupl_pt_348',
#  'data_with_dupl_pt_349',
#  'data_with_dupl_pt_350',
#  'data_with_dupl_pt_351',
#  'data_with_dupl_pt_352',
#  'data_with_dupl_pt_353',
#  'data_with_dupl_pt_354',
#  'data_with_dupl_pt_355',
#  'data_with_dupl_pt_356',
#  'data_with_dupl_pt_357',
#  'data_with_dupl_pt_358',
#  'data_with_dupl_pt_359',
#  'data_with_dupl_pt_360',
#  'data_with_dupl_pt_361',
#  'data_with_dupl_pt_362',
#  'data_with_dupl_pt_363']

# %%
len(data_chunks)
# Out:
# 363

# %%
for i in range(len(filenames)):
    filename = 'data_with_duplicates_by_parts/'+filenames[i]+'.csv'
    with open(filename, 'a', encoding='utf-8') as f:
        for el in data_chunks[i]:
            f.write(el)

# %% [markdown]
# ### Below we chunk our dataset into parts in order to avoid overload of RAM while computing the whole dataset

# %%
data_chunks = [data[x:x+100] for x in range(0, len(data), 100)]

# %%
import os
all_files = os.listdir('data_with_duplicates_by_parts')
all_files_src = ['data_with_duplicates_by_parts/'+f for f in all_files]
all_files_src
# Out:
# ['data_with_duplicates_by_parts/data_with_dupl_pt_1.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_10.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_100.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_101.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_102.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_103.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_104.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_105.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_106.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_107.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_108.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_109.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_11.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_110.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_111.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_112.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_113.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_114.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_115.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_116.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_117.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_118.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_119.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_12.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_120.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_121.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_122.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_123.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_124.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_125.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_126.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_127.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_128.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_129.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_13.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_130.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_131.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_132.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_133.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_134.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_135.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_136.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_137.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_138.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_139.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_14.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_140.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_141.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_142.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_143.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_144.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_145.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_146.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_147.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_148.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_149.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_15.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_150.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_151.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_152.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_153.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_154.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_155.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_156.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_157.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_158.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_159.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_16.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_160.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_161.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_162.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_163.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_164.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_165.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_166.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_167.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_168.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_169.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_17.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_170.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_171.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_172.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_173.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_174.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_175.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_176.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_177.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_178.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_179.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_18.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_180.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_181.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_182.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_183.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_184.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_185.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_186.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_187.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_188.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_189.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_19.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_190.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_191.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_192.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_193.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_194.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_195.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_196.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_197.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_198.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_199.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_2.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_20.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_200.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_201.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_202.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_203.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_204.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_205.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_206.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_207.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_208.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_209.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_21.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_210.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_211.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_212.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_213.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_214.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_215.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_216.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_217.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_218.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_219.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_22.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_220.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_221.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_222.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_223.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_224.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_225.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_226.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_227.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_228.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_229.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_23.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_230.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_231.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_232.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_233.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_234.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_235.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_236.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_237.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_238.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_239.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_24.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_240.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_241.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_242.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_243.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_244.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_245.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_246.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_247.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_248.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_249.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_25.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_250.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_251.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_252.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_253.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_254.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_255.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_256.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_257.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_258.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_259.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_26.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_260.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_261.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_262.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_263.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_264.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_265.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_266.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_267.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_268.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_269.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_27.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_270.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_271.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_272.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_273.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_274.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_275.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_276.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_277.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_278.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_279.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_28.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_280.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_281.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_282.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_283.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_284.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_285.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_286.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_287.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_288.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_289.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_29.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_290.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_291.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_292.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_293.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_294.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_295.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_296.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_297.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_298.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_299.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_3.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_30.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_300.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_301.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_302.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_303.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_304.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_305.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_306.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_307.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_308.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_309.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_31.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_310.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_311.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_312.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_313.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_314.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_315.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_316.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_317.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_318.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_319.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_32.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_320.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_321.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_322.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_323.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_324.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_325.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_326.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_327.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_328.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_329.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_33.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_330.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_331.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_332.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_333.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_334.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_335.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_336.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_337.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_338.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_339.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_34.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_340.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_341.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_342.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_343.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_344.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_345.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_346.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_347.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_348.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_349.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_35.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_350.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_351.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_352.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_353.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_354.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_355.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_356.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_357.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_358.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_359.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_36.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_360.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_361.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_362.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_363.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_37.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_38.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_39.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_4.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_40.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_41.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_42.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_43.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_44.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_45.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_46.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_47.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_48.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_49.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_5.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_50.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_51.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_52.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_53.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_54.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_55.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_56.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_57.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_58.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_59.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_6.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_60.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_61.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_62.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_63.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_64.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_65.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_66.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_67.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_68.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_69.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_7.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_70.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_71.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_72.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_73.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_74.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_75.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_76.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_77.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_78.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_79.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_8.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_80.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_81.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_82.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_83.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_84.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_85.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_86.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_87.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_88.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_89.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_9.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_90.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_91.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_92.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_93.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_94.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_95.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_96.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_97.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_98.csv',
#  'data_with_duplicates_by_parts/data_with_dupl_pt_99.csv']

# %%
os.mkdir('with_duplicates_by_parts_final')

# %%
#os.mkdir('no_duplicates_by_parts_final')
new_files = ['with_duplicates_by_parts_final/'+f for f in all_files]

# %%
new_files
# Out:
# ['with_duplicates_by_parts_final/data_with_dupl_pt_1.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_10.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_100.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_101.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_102.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_103.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_104.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_105.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_106.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_107.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_108.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_109.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_11.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_110.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_111.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_112.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_113.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_114.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_115.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_116.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_117.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_118.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_119.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_12.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_120.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_121.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_122.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_123.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_124.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_125.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_126.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_127.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_128.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_129.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_13.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_130.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_131.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_132.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_133.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_134.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_135.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_136.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_137.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_138.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_139.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_14.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_140.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_141.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_142.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_143.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_144.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_145.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_146.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_147.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_148.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_149.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_15.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_150.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_151.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_152.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_153.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_154.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_155.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_156.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_157.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_158.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_159.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_16.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_160.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_161.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_162.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_163.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_164.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_165.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_166.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_167.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_168.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_169.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_17.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_170.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_171.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_172.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_173.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_174.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_175.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_176.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_177.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_178.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_179.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_18.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_180.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_181.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_182.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_183.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_184.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_185.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_186.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_187.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_188.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_189.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_19.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_190.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_191.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_192.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_193.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_194.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_195.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_196.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_197.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_198.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_199.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_2.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_20.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_200.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_201.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_202.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_203.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_204.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_205.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_206.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_207.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_208.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_209.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_21.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_210.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_211.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_212.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_213.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_214.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_215.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_216.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_217.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_218.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_219.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_22.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_220.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_221.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_222.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_223.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_224.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_225.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_226.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_227.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_228.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_229.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_23.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_230.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_231.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_232.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_233.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_234.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_235.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_236.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_237.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_238.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_239.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_24.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_240.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_241.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_242.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_243.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_244.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_245.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_246.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_247.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_248.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_249.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_25.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_250.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_251.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_252.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_253.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_254.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_255.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_256.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_257.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_258.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_259.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_26.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_260.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_261.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_262.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_263.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_264.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_265.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_266.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_267.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_268.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_269.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_27.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_270.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_271.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_272.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_273.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_274.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_275.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_276.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_277.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_278.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_279.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_28.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_280.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_281.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_282.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_283.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_284.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_285.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_286.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_287.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_288.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_289.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_29.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_290.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_291.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_292.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_293.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_294.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_295.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_296.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_297.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_298.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_299.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_3.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_30.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_300.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_301.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_302.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_303.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_304.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_305.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_306.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_307.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_308.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_309.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_31.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_310.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_311.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_312.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_313.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_314.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_315.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_316.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_317.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_318.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_319.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_32.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_320.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_321.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_322.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_323.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_324.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_325.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_326.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_327.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_328.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_329.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_33.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_330.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_331.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_332.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_333.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_334.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_335.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_336.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_337.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_338.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_339.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_34.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_340.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_341.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_342.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_343.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_344.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_345.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_346.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_347.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_348.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_349.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_35.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_350.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_351.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_352.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_353.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_354.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_355.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_356.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_357.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_358.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_359.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_36.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_360.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_361.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_362.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_363.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_37.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_38.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_39.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_4.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_40.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_41.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_42.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_43.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_44.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_45.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_46.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_47.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_48.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_49.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_5.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_50.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_51.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_52.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_53.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_54.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_55.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_56.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_57.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_58.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_59.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_6.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_60.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_61.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_62.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_63.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_64.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_65.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_66.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_67.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_68.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_69.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_7.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_70.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_71.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_72.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_73.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_74.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_75.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_76.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_77.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_78.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_79.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_8.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_80.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_81.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_82.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_83.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_84.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_85.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_86.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_87.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_88.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_89.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_9.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_90.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_91.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_92.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_93.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_94.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_95.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_96.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_97.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_98.csv',
#  'with_duplicates_by_parts_final/data_with_dupl_pt_99.csv']

# %%
import re
with open('data_with_duplicates_final.csv', 'w', encoding='utf-8') as f:
    f.write('wiki_id,label_zh,label_ru,country,type,xinhua,\n') #levenstein_abs,levenstein_normalized,jaccard
import time
idx = 0
for i  in range(len(all_files)):
    with open(all_files_src[i], 'r', encoding='utf-8') as src:
        #print('reading source')
        f_lines = src.readlines()
    print(all_files_src[i]+' is processed...')
    idx += 1
    for line in f_lines:
        #print('working on line:')
        line = line[:-1]
        #print('line')
        wiki_id, to_compare, to_translate, c, t = line.split(',')[0], line.split(',')[1], line.split(',')[2], line.split(',')[3], line.split(',')[4]
        #print(to_compare, to_translate)
        to_translate = re.sub(r'[«»]', r'', to_translate)
        to_compare = HanziConv.toSimplified(to_compare)
        translation = T(to_translate, table).output_word
        new_line = wiki_id +','+ to_compare +','+ to_translate +',' + translation +',' + c +','+ t + '\n' #','+str(lev_abs)+','+str(lev_norm)+','+str(jac)+
        #print(new_line)
        #print('result is ready')
        with open(new_files[i], 'a', encoding='utf-8') as output:
        #    print('writing to new line')
            output.write(new_line)
        with open('data_with_duplicates_final.csv', 'w', encoding='utf-8') as final_file:
            final_file.write(new_line)
        #print('done! next line!')
    print(f'chunk {idx} completed')
    time.sleep(1)
# Out:
# data_with_duplicates_by_parts/data_with_dupl_pt_1.csv is processed...
# chunk 1 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_10.csv is processed...
# chunk 2 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_100.csv is processed...
# chunk 3 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_101.csv is processed...
# chunk 4 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_102.csv is processed...
# chunk 5 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_103.csv is processed...
# chunk 6 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_104.csv is processed...
# chunk 7 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_105.csv is processed...
# chunk 8 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_106.csv is processed...
# chunk 9 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_107.csv is processed...
# chunk 10 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_108.csv is processed...
# chunk 11 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_109.csv is processed...
# chunk 12 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_11.csv is processed...
# chunk 13 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_110.csv is processed...
# chunk 14 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_111.csv is processed...
# chunk 15 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_112.csv is processed...
# chunk 16 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_113.csv is processed...
# chunk 17 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_114.csv is processed...
# chunk 18 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_115.csv is processed...
# chunk 19 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_116.csv is processed...
# chunk 20 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_117.csv is processed...
# chunk 21 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_118.csv is processed...
# chunk 22 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_119.csv is processed...
# chunk 23 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_12.csv is processed...
# chunk 24 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_120.csv is processed...
# chunk 25 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_121.csv is processed...
# chunk 26 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_122.csv is processed...
# chunk 27 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_123.csv is processed...
# chunk 28 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_124.csv is processed...
# chunk 29 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_125.csv is processed...
# chunk 30 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_126.csv is processed...
# chunk 31 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_127.csv is processed...
# chunk 32 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_128.csv is processed...
# chunk 33 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_129.csv is processed...
# chunk 34 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_13.csv is processed...
# chunk 35 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_130.csv is processed...
# chunk 36 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_131.csv is processed...
# chunk 37 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_132.csv is processed...
# chunk 38 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_133.csv is processed...
# chunk 39 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_134.csv is processed...
# chunk 40 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_135.csv is processed...
# chunk 41 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_136.csv is processed...
# chunk 42 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_137.csv is processed...
# chunk 43 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_138.csv is processed...
# chunk 44 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_139.csv is processed...
# chunk 45 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_14.csv is processed...
# chunk 46 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_140.csv is processed...
# chunk 47 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_141.csv is processed...
# chunk 48 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_142.csv is processed...
# chunk 49 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_143.csv is processed...
# chunk 50 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_144.csv is processed...
# chunk 51 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_145.csv is processed...
# chunk 52 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_146.csv is processed...
# chunk 53 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_147.csv is processed...
# chunk 54 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_148.csv is processed...
# chunk 55 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_149.csv is processed...
# chunk 56 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_15.csv is processed...
# chunk 57 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_150.csv is processed...
# chunk 58 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_151.csv is processed...
# chunk 59 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_152.csv is processed...
# chunk 60 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_153.csv is processed...
# chunk 61 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_154.csv is processed...
# chunk 62 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_155.csv is processed...
# chunk 63 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_156.csv is processed...
# chunk 64 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_157.csv is processed...
# chunk 65 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_158.csv is processed...
# chunk 66 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_159.csv is processed...
# chunk 67 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_16.csv is processed...
# chunk 68 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_160.csv is processed...
# chunk 69 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_161.csv is processed...
# chunk 70 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_162.csv is processed...
# chunk 71 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_163.csv is processed...
# chunk 72 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_164.csv is processed...
# chunk 73 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_165.csv is processed...
# chunk 74 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_166.csv is processed...
# chunk 75 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_167.csv is processed...
# chunk 76 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_168.csv is processed...
# chunk 77 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_169.csv is processed...
# chunk 78 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_17.csv is processed...
# chunk 79 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_170.csv is processed...
# chunk 80 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_171.csv is processed...
# chunk 81 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_172.csv is processed...
# chunk 82 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_173.csv is processed...
# chunk 83 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_174.csv is processed...
# chunk 84 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_175.csv is processed...
# chunk 85 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_176.csv is processed...
# chunk 86 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_177.csv is processed...
# chunk 87 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_178.csv is processed...
# chunk 88 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_179.csv is processed...
# chunk 89 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_18.csv is processed...
# chunk 90 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_180.csv is processed...
# chunk 91 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_181.csv is processed...
# chunk 92 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_182.csv is processed...
# chunk 93 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_183.csv is processed...
# chunk 94 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_184.csv is processed...
# chunk 95 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_185.csv is processed...
# chunk 96 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_186.csv is processed...
# chunk 97 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_187.csv is processed...
# chunk 98 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_188.csv is processed...
# chunk 99 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_189.csv is processed...
# chunk 100 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_19.csv is processed...
# chunk 101 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_190.csv is processed...
# chunk 102 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_191.csv is processed...
# chunk 103 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_192.csv is processed...
# chunk 104 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_193.csv is processed...
# chunk 105 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_194.csv is processed...
# chunk 106 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_195.csv is processed...
# chunk 107 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_196.csv is processed...
# chunk 108 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_197.csv is processed...
# chunk 109 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_198.csv is processed...
# chunk 110 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_199.csv is processed...
# chunk 111 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_2.csv is processed...
# chunk 112 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_20.csv is processed...
# chunk 113 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_200.csv is processed...
# chunk 114 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_201.csv is processed...
# chunk 115 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_202.csv is processed...
# chunk 116 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_203.csv is processed...
# chunk 117 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_204.csv is processed...
# chunk 118 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_205.csv is processed...
# chunk 119 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_206.csv is processed...
# chunk 120 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_207.csv is processed...
# chunk 121 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_208.csv is processed...
# chunk 122 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_209.csv is processed...
# chunk 123 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_21.csv is processed...
# chunk 124 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_210.csv is processed...
# chunk 125 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_211.csv is processed...
# chunk 126 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_212.csv is processed...
# chunk 127 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_213.csv is processed...
# chunk 128 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_214.csv is processed...
# chunk 129 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_215.csv is processed...
# chunk 130 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_216.csv is processed...
# chunk 131 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_217.csv is processed...
# chunk 132 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_218.csv is processed...
# chunk 133 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_219.csv is processed...
# chunk 134 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_22.csv is processed...
# chunk 135 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_220.csv is processed...
# chunk 136 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_221.csv is processed...
# chunk 137 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_222.csv is processed...
# chunk 138 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_223.csv is processed...
# chunk 139 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_224.csv is processed...
# chunk 140 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_225.csv is processed...
# chunk 141 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_226.csv is processed...
# chunk 142 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_227.csv is processed...
# chunk 143 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_228.csv is processed...
# chunk 144 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_229.csv is processed...
# chunk 145 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_23.csv is processed...
# chunk 146 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_230.csv is processed...
# chunk 147 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_231.csv is processed...
# chunk 148 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_232.csv is processed...
# chunk 149 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_233.csv is processed...
# chunk 150 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_234.csv is processed...
# chunk 151 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_235.csv is processed...
# chunk 152 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_236.csv is processed...
# chunk 153 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_237.csv is processed...
# chunk 154 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_238.csv is processed...
# chunk 155 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_239.csv is processed...
# chunk 156 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_24.csv is processed...
# chunk 157 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_240.csv is processed...
# chunk 158 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_241.csv is processed...
# chunk 159 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_242.csv is processed...
# chunk 160 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_243.csv is processed...
# chunk 161 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_244.csv is processed...
# chunk 162 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_245.csv is processed...
# chunk 163 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_246.csv is processed...
# chunk 164 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_247.csv is processed...
# chunk 165 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_248.csv is processed...
# chunk 166 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_249.csv is processed...
# chunk 167 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_25.csv is processed...
# chunk 168 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_250.csv is processed...
# chunk 169 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_251.csv is processed...
# chunk 170 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_252.csv is processed...
# chunk 171 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_253.csv is processed...
# chunk 172 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_254.csv is processed...
# chunk 173 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_255.csv is processed...
# chunk 174 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_256.csv is processed...
# chunk 175 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_257.csv is processed...
# chunk 176 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_258.csv is processed...
# chunk 177 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_259.csv is processed...
# chunk 178 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_26.csv is processed...
# chunk 179 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_260.csv is processed...
# chunk 180 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_261.csv is processed...
# chunk 181 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_262.csv is processed...
# chunk 182 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_263.csv is processed...
# chunk 183 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_264.csv is processed...
# chunk 184 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_265.csv is processed...
# chunk 185 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_266.csv is processed...
# chunk 186 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_267.csv is processed...
# chunk 187 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_268.csv is processed...
# chunk 188 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_269.csv is processed...
# chunk 189 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_27.csv is processed...
# chunk 190 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_270.csv is processed...
# chunk 191 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_271.csv is processed...
# chunk 192 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_272.csv is processed...
# chunk 193 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_273.csv is processed...
# chunk 194 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_274.csv is processed...
# chunk 195 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_275.csv is processed...
# chunk 196 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_276.csv is processed...
# chunk 197 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_277.csv is processed...
# chunk 198 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_278.csv is processed...
# chunk 199 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_279.csv is processed...
# chunk 200 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_28.csv is processed...
# chunk 201 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_280.csv is processed...
# chunk 202 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_281.csv is processed...
# chunk 203 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_282.csv is processed...
# chunk 204 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_283.csv is processed...
# chunk 205 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_284.csv is processed...
# chunk 206 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_285.csv is processed...
# chunk 207 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_286.csv is processed...
# chunk 208 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_287.csv is processed...
# chunk 209 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_288.csv is processed...
# chunk 210 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_289.csv is processed...
# chunk 211 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_29.csv is processed...
# chunk 212 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_290.csv is processed...
# chunk 213 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_291.csv is processed...
# chunk 214 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_292.csv is processed...
# chunk 215 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_293.csv is processed...
# chunk 216 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_294.csv is processed...
# chunk 217 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_295.csv is processed...
# chunk 218 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_296.csv is processed...
# chunk 219 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_297.csv is processed...
# chunk 220 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_298.csv is processed...
# chunk 221 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_299.csv is processed...
# chunk 222 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_3.csv is processed...
# chunk 223 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_30.csv is processed...
# chunk 224 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_300.csv is processed...
# chunk 225 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_301.csv is processed...
# chunk 226 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_302.csv is processed...
# chunk 227 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_303.csv is processed...
# chunk 228 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_304.csv is processed...
# chunk 229 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_305.csv is processed...
# chunk 230 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_306.csv is processed...
# chunk 231 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_307.csv is processed...
# chunk 232 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_308.csv is processed...
# chunk 233 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_309.csv is processed...
# chunk 234 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_31.csv is processed...
# chunk 235 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_310.csv is processed...
# chunk 236 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_311.csv is processed...
# chunk 237 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_312.csv is processed...
# chunk 238 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_313.csv is processed...
# chunk 239 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_314.csv is processed...
# chunk 240 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_315.csv is processed...
# chunk 241 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_316.csv is processed...
# chunk 242 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_317.csv is processed...
# chunk 243 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_318.csv is processed...
# chunk 244 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_319.csv is processed...
# chunk 245 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_32.csv is processed...
# chunk 246 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_320.csv is processed...
# chunk 247 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_321.csv is processed...
# chunk 248 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_322.csv is processed...
# chunk 249 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_323.csv is processed...
# chunk 250 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_324.csv is processed...
# chunk 251 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_325.csv is processed...
# chunk 252 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_326.csv is processed...
# chunk 253 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_327.csv is processed...
# chunk 254 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_328.csv is processed...
# chunk 255 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_329.csv is processed...
# chunk 256 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_33.csv is processed...
# chunk 257 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_330.csv is processed...
# chunk 258 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_331.csv is processed...
# chunk 259 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_332.csv is processed...
# chunk 260 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_333.csv is processed...
# chunk 261 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_334.csv is processed...
# chunk 262 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_335.csv is processed...
# chunk 263 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_336.csv is processed...
# chunk 264 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_337.csv is processed...
# chunk 265 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_338.csv is processed...
# chunk 266 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_339.csv is processed...
# chunk 267 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_34.csv is processed...
# chunk 268 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_340.csv is processed...
# chunk 269 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_341.csv is processed...
# chunk 270 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_342.csv is processed...
# chunk 271 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_343.csv is processed...
# chunk 272 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_344.csv is processed...
# chunk 273 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_345.csv is processed...
# chunk 274 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_346.csv is processed...
# chunk 275 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_347.csv is processed...
# chunk 276 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_348.csv is processed...
# chunk 277 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_349.csv is processed...
# chunk 278 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_35.csv is processed...
# chunk 279 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_350.csv is processed...
# chunk 280 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_351.csv is processed...
# chunk 281 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_352.csv is processed...
# chunk 282 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_353.csv is processed...
# chunk 283 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_354.csv is processed...
# chunk 284 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_355.csv is processed...
# chunk 285 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_356.csv is processed...
# chunk 286 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_357.csv is processed...
# chunk 287 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_358.csv is processed...
# chunk 288 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_359.csv is processed...
# chunk 289 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_36.csv is processed...
# chunk 290 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_360.csv is processed...
# chunk 291 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_361.csv is processed...
# chunk 292 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_362.csv is processed...
# chunk 293 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_363.csv is processed...
# chunk 294 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_37.csv is processed...
# chunk 295 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_38.csv is processed...
# chunk 296 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_39.csv is processed...
# chunk 297 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_4.csv is processed...
# chunk 298 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_40.csv is processed...
# chunk 299 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_41.csv is processed...
# chunk 300 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_42.csv is processed...
# chunk 301 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_43.csv is processed...
# chunk 302 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_44.csv is processed...
# chunk 303 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_45.csv is processed...
# chunk 304 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_46.csv is processed...
# chunk 305 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_47.csv is processed...
# chunk 306 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_48.csv is processed...
# chunk 307 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_49.csv is processed...
# chunk 308 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_5.csv is processed...
# chunk 309 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_50.csv is processed...
# chunk 310 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_51.csv is processed...
# chunk 311 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_52.csv is processed...
# chunk 312 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_53.csv is processed...
# chunk 313 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_54.csv is processed...
# chunk 314 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_55.csv is processed...
# chunk 315 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_56.csv is processed...
# chunk 316 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_57.csv is processed...
# chunk 317 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_58.csv is processed...
# chunk 318 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_59.csv is processed...
# chunk 319 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_6.csv is processed...
# chunk 320 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_60.csv is processed...
# chunk 321 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_61.csv is processed...
# chunk 322 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_62.csv is processed...
# chunk 323 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_63.csv is processed...
# chunk 324 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_64.csv is processed...
# chunk 325 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_65.csv is processed...
# chunk 326 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_66.csv is processed...
# chunk 327 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_67.csv is processed...
# chunk 328 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_68.csv is processed...
# chunk 329 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_69.csv is processed...
# chunk 330 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_7.csv is processed...
# chunk 331 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_70.csv is processed...
# chunk 332 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_71.csv is processed...
# chunk 333 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_72.csv is processed...
# chunk 334 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_73.csv is processed...
# chunk 335 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_74.csv is processed...
# chunk 336 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_75.csv is processed...
# chunk 337 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_76.csv is processed...
# chunk 338 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_77.csv is processed...
# chunk 339 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_78.csv is processed...
# chunk 340 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_79.csv is processed...
# chunk 341 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_8.csv is processed...
# chunk 342 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_80.csv is processed...
# chunk 343 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_81.csv is processed...
# chunk 344 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_82.csv is processed...
# chunk 345 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_83.csv is processed...
# chunk 346 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_84.csv is processed...
# chunk 347 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_85.csv is processed...
# chunk 348 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_86.csv is processed...
# chunk 349 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_87.csv is processed...
# chunk 350 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_88.csv is processed...
# chunk 351 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_89.csv is processed...
# chunk 352 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_9.csv is processed...
# chunk 353 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_90.csv is processed...
# chunk 354 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_91.csv is processed...
# chunk 355 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_92.csv is processed...
# chunk 356 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_93.csv is processed...
# chunk 357 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_94.csv is processed...
# chunk 358 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_95.csv is processed...
# chunk 359 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_96.csv is processed...
# chunk 360 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_97.csv is processed...
# chunk 361 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_98.csv is processed...
# chunk 362 completed
# data_with_duplicates_by_parts/data_with_dupl_pt_99.csv is processed...
# chunk 363 completed

# %% [markdown]
# ### Now we aggregate all the files into one .csv dataset again

# %%
res = os.listdir('with_duplicates_by_parts_final')
res = ['with_duplicates_by_parts_final/'+l for l in res]

# %%
with open('data_with_duplicates_final.csv', 'w', encoding='utf-8') as f:
    f.write('wiki_id,label_zh,label_ru,xinhua,country,type\n')
for i in range(len(res)):
    with open (res[i], 'r', encoding='utf-8') as src:
        lines = src.readlines()
    with open('data_with_duplicates_final.csv', 'a', encoding='utf-8') as f:
        for l in lines:
            f.write(l)

# %%
d = pd.read_csv('data_with_duplicates_final.csv')
d = d[~d['label_zh'].str.contains("[a-zA-ZА-Яа-я]").fillna(False)]
#d = d.replace(to_replace=r'·', value=r'',regex=True)
d.shape
# Out:
# (36250, 6)

# %%
d.head()
# Out:
#    wiki_id label_zh    label_ru  xinhua country  type  levenstein_abs  \
# 0   265997     伊曼德拉     Имандра    伊曼德拉  Russia  lake               0
# 1   166162      奥涅加    Онежское  奥涅日斯科耶  Russia  lake               4
# 2   233071       汉泰  Хантайское   汉泰斯科耶  Russia  lake               3
# 3   245763   奥特拉德诺耶    Отрадное  奥特拉德诺耶  Russia  lake               0
# 4   117036     绍托泽罗    Шотозеро    绍托泽罗  Russia  lake               0
#
#    levenstein_norm   jaccard
# 0         0.000000  1.000000
# 1         0.666667  0.285714
# 2         0.600000  0.400000
# 3         0.000000  1.000000
# 4         0.000000  1.000000

# %% [markdown]
# ### Applying 3 metrics

# %%
d["levenstein_abs"] = d.loc[:, ["label_zh","xinhua"]].apply(lambda x: textdistance.levenshtein.distance(*x), axis=1)

# %%
d["levenstein_norm"] = d.loc[:, ["label_zh","xinhua"]].apply(lambda x: textdistance.levenshtein.normalized_distance(*x), axis=1)

# %%
d["jaccard"] = d.loc[:, ["label_zh","xinhua"]].apply(lambda x: textdistance.jaccard(*x), axis=1)

# %% [markdown]
# ### Saving to the final dataset

# %%
d.to_csv('data_total.csv')
